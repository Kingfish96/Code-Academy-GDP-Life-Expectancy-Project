# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv(r"C:\Users\Jose\Downloads\Life-Expectancy-and-GDP-Starter\all_data.csv")

# %%
df.tail()
# Out:
#      Country  Year  Life expectancy at birth (years)           GDP
# 91  Zimbabwe  2011                              54.9  1.209845e+10
# 92  Zimbabwe  2012                              56.6  1.424249e+10
# 93  Zimbabwe  2013                              58.0  1.545177e+10
# 94  Zimbabwe  2014                              59.2  1.589105e+10
# 95  Zimbabwe  2015                              60.7  1.630467e+10

# %%
plt.plot(df["Country"], df["Life expectancy at birth (years)"])
plt.xlabel('Countries')
plt.ylabel('Life Expectancy')
plt.title('Comparing Countries and their Average Life Expectancies')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.bar(df['Country'], df['Life expectancy at birth (years)'])
plt.xlabel('Country')
plt.ylabel('Life Expectancies']
plt.title('Countries and their Life Expectancies)
plt.xticks(rotation
# Out:
#   Cell In[67], line 2
#     plt.xlabel('Country']
#                         ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
